# %% [markdown]
# # 第2章: UNIXコマンド

# %% [markdown]
# popular-names.txtは，アメリカで生まれた赤ちゃんの「名前」「性別」「人数」「年」をタブ区切り形式で格納したファイルである．以下の処理を行うプログラムを作成し，popular-names.txtを入力ファイルとして実行せよ．さらに，同様の処理をUNIXコマンドでも実行し，プログラムの実行結果を確認せよ

# %%
import pandas as pd

# %% [markdown]
# ## 10. 行数のカウント
# 行数をカウントせよ．確認にはwcコマンドを用いよ．

# %%
df = pd.read_csv("./data/popular-names.txt",sep="\t",header=None)

# %%
len(df)
# Out:
# 2780

# %%
# !wc -l ./data/popular-names.txt
# Out:
#     2780 ./data/popular-names.txt

# %% [markdown]
# - -c	--bytes	バイト数を表示する
# - -m	--chars	文字数を表示する（マルチバイト文字に対応）
# - -l	--lines	改行の数を表示する
# - -w	--words	単語数を表示する
# - -L	--max-line-length	最も長い行の長さを表示する
# - --files0-from=リスト	NULL文字で区切られたファイル名のリストを指定する（「--files0-from=- 」とした場合は、ファイル名を標準入力から読み込む）

# %% [markdown]
# ## 11. タブをスペースに置換
# タブ1文字につきスペース1文字に置換せよ．確認にはsedコマンド，trコマンド，もしくはexpandコマンドを用いよ．

# %%
df.to_csv('data/2/11.txt', sep=' ', index=False, header=None)
pd.read_csv('data/2/11.txt').head()
# Out:
#         Mary F 7065 1880
# 0       Anna F 2604 1880
# 1       Emma F 2003 1880
# 2  Elizabeth F 1939 1880
# 3     Minnie F 1746 1880
# 4   Margaret F 1578 1880

# %% [markdown]
# ## 12. 1列目をcol1.txtに，2列目をcol2.txtに保存Permalink
# 各行の1列目だけを抜き出したものをcol1.txtに，2列目だけを抜き出したものをcol2.txtとしてファイルに保存せよ．確認にはcutコマンドを用いよ．

# %%
df.head()
# Out:
#            0  1     2     3
# 0       Mary  F  7065  1880
# 1       Anna  F  2604  1880
# 2       Emma  F  2003  1880
# 3  Elizabeth  F  1939  1880
# 4     Minnie  F  1746  1880

# %%
df[0].to_csv('data/2/col1.txt',index=False, header=None)
df[1].to_csv('data/2/col2.txt',index=False, header=None)

# %% [markdown]
# ## 13. col1.txtとcol2.txtをマージPermalink
# 12で作ったcol1.txtとcol2.txtを結合し，元のファイルの1列目と2列目をタブ区切りで並べたテキストファイルを作成せよ．確認にはpasteコマンドを用いよ．

# %%
col1 = pd.read_csv('data/2/col1.txt',header=None)
col2 = pd.read_csv('data/2/col2.txt',header=None)

# %%
merged_df = pd.concat([col1,col2],axis=1)

# %%
merged_df.head()
# Out:
#            0  0
# 0       Mary  F
# 1       Anna  F
# 2       Emma  F
# 3  Elizabeth  F
# 4     Minnie  F

# %%
merged_df.to_csv('data/2/13.txt', sep='\t', index=False, header=None)

# %%
# !paste -d '\t' data/2/col[1-2].txt
# Out:
# Mary	F
# Anna	F
# Emma	F
# Elizabeth	F
# Minnie	F
# Margaret	F
# Ida	F
# Alice	F
# Bertha	F
# Sarah	F
# John	M
# William	M
# James	M
# Charles	M
# George	M
# Frank	M
# Joseph	M
# Thomas	M
# Henry	M
# Robert	M
# Mary	F
# Anna	F
# Emma	F
# Elizabeth	F
# Margaret	F
# Minnie	F
# Ida	F
# Annie	F
# Bertha	F
# Alice	F
# John	M
# William	M
# James	M
# George	M
# Charles	M
# Frank	M
# Joseph	M
# Henry	M
# Thomas	M
# Edward	M
# Mary	F
# Anna	F
# Emma	F
# Elizabeth	F
# Minnie	F
# Margaret	F
# Ida	F
# Alice	F
# Bertha	F
# Annie	F
# John	M
# William	M
# James	M
# George	M
# Charles	M
# Frank	M
# Joseph	M
# Thomas	M
# Henry	M
# Robert	M
# Mary	F
# Anna	F
# Emma	F
# Elizabeth	F
# Minnie	F
# Margaret	F
# Bertha	F
# Ida	F
# Annie	F
# Clara	F
# John	M
# William	M
# James	M
# Charles	M
# George	M
# Frank	M
# Joseph	M
# Henry	M
# Robert	M
# Thomas	M
# Mary	F
# Anna	F
# Emma	F
# Elizabeth	F
# Minnie	F
# Margaret	F
# Ida	F
# Clara	F
# Bertha	F
# Annie	F
# John	M
# William	M
# James	M
# George	M
# ...

# %% [markdown]
# ## 14. 先頭からN行を出力Permalink
# 自然数Nをコマンドライン引数などの手段で受け取り，入力のうち先頭のN行だけを表示せよ．確認にはheadコマンドを用いよ．

# %%
def head_list(df,n):
    return df.head(n)

# %%
head_list(df,8)
# Out:
#            0  1     2     3
# 0       Mary  F  7065  1880
# 1       Anna  F  2604  1880
# 2       Emma  F  2003  1880
# 3  Elizabeth  F  1939  1880
# 4     Minnie  F  1746  1880
# 5   Margaret  F  1578  1880
# 6        Ida  F  1472  1880
# 7      Alice  F  1414  1880

# %%
# !head -n 8 ./data/2/popular-names.txt
# Out:
# Mary	F	7065	1880
# Anna	F	2604	1880
# Emma	F	2003	1880
# Elizabeth	F	1939	1880
# Minnie	F	1746	1880
# Margaret	F	1578	1880
# Ida	F	1472	1880
# Alice	F	1414	1880

# %% [markdown]
# - -c 数字	--bytes 数字	先頭から指定したバイト数のみ表示する。「-c 5 b」のように単位を付加することも可能（b=512, KB=1000, K=1024, MB=1000*1000, M=1024*1024…）
# - -n 数字	--lines 数字	先頭から指定した行数のみ表示する
# - -q 	--quiet, --silent	ファイルごとのヘッダ表示を行わない（複数ファイル指定時に使う）
# - -v	--verbose	常にファイルごとのヘッダ出力を行う

# %% [markdown]
# ## 15. 末尾のN行を出力
# 自然数Nをコマンドライン引数などの手段で受け取り，入力のうち末尾のN行だけを表示せよ．確認にはtailコマンドを用いよ

# %%
def tail_list(df,n):
    return df.tail(n)

# %%
tail_list(df,8)
# Out:
#              0  1      2     3
# 2772   William  M  14516  2018
# 2773     James  M  13525  2018
# 2774    Oliver  M  13389  2018
# 2775  Benjamin  M  13381  2018
# 2776    Elijah  M  12886  2018
# 2777     Lucas  M  12585  2018
# 2778     Mason  M  12435  2018
# 2779     Logan  M  12352  2018

# %%
# !tail -n 8 'data/2/popular-names.txt'
# Out:
# William	M	14516	2018
# James	M	13525	2018
# Oliver	M	13389	2018
# Benjamin	M	13381	2018
# Elijah	M	12886	2018
# Lucas	M	12585	2018
# Mason	M	12435	2018
# Logan	M	12352	2018

# %% [markdown]
# ## 16. ファイルをN分割する
# 自然数Nをコマンドライン引数などの手段で受け取り，入力のファイルを行単位でN分割せよ．同様の処理をsplitコマンドで実現せよ．

# %%
def split_list(df,n):

# %%
# !split -n 3 data/2/popular-names.txt test-.txt
# Out:
# split: illegal option -- n
# usage: split [-a sufflen] [-b byte_count] [-l line_count] [-p pattern]
#              [file [prefix]]
